# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

models = [
    "Logistic\nRegression",
    "XGBoost",
    "ESM2-3B\n+ MLP",
    "ProtBERT-BFD\n+ MLP",
    "DGEB\nBaseline",
]

ap_scores = [0.41, 0.40, 0.45, 0.5074, 0.5247]
colors = ["#5B8DB8", "#5B8DB8", "#E8A838", "#E8A838", "#6BBF7A"]

fig, ax = plt.subplots(figsize=(9, 5))

bars = ax.bar(models, ap_scores, color=colors, width=0.5, edgecolor="white", linewidth=0.8)

for bar, score in zip(bars, ap_scores):
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height() + 0.005,
        f"{score:.4f}",
        ha="center", va="bottom", fontsize=9, fontweight="bold"
    )

legend_elements = [
    Patch(facecolor="#5B8DB8", label="Physicochemical Baselines"),
    Patch(facecolor="#E8A838", label="Siamese MLP (Ours)"),
    Patch(facecolor="#6BBF7A", label="DGEB Baseline"),
]
ax.legend(handles=legend_elements, loc="lower right", fontsize=9)

ax.set_ylim(0, 0.65)
ax.set_ylabel("Average Precision (AP)", fontsize=11)
ax.set_title("Average Precision by Model on Operon Pair Classification", fontsize=12, fontweight="bold")
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.yaxis.grid(True, linestyle="--", alpha=0.5)
ax.set_axisbelow(True)

plt.tight_layout()
plt.savefig("average_precision_comparison.png", dpi=150, bbox_inches="tight")
plt.show()
print("Saved to average_precision_comparison.png")
# Out:
# Saved to average_precision_comparison.png

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

models = [
    "Logistic\nRegression",
    "XGBoost",
    "ESM2-3B\n+ MLP",
    "ProtBERT-BFD\n+ MLP",
]

auc_scores = [0.6252, 0.6160, 0.7104, 0.7064]
colors = ["#5B8DB8", "#5B8DB8", "#E8A838", "#E8A838"]

fig, ax = plt.subplots(figsize=(8, 5))

bars = ax.bar(models, auc_scores, color=colors, width=0.5, edgecolor="white", linewidth=0.8)

for bar, score in zip(bars, auc_scores):
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height() + 0.003,
        f"{score:.4f}",
        ha="center", va="bottom", fontsize=9, fontweight="bold"
    )

legend_elements = [
    Patch(facecolor="#5B8DB8", label="Physicochemical Baselines"),
    Patch(facecolor="#E8A838", label="Siamese MLP (Ours)"),
]
ax.legend(handles=legend_elements, loc="lower right", fontsize=9)

ax.set_ylim(0.5, 0.80)
ax.set_ylabel("ROC-AUC", fontsize=11)
ax.set_title("ROC-AUC by Model on Operon Pair Classification", fontsize=12, fontweight="bold")
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.yaxis.grid(True, linestyle="--", alpha=0.5)
ax.set_axisbelow(True)

plt.tight_layout()
plt.savefig("roc_auc_comparison.png", dpi=150, bbox_inches="tight")
plt.show()
print("Saved to roc_auc_comparison.png")
# Out:
# Saved to roc_auc_comparison.png
